# %%
# %matplotlib inline

import models
import data
import matplotlib.pyplot as plt
# Out:
# WARNING:root:Argument whitelist is deprecated. Please use allowlist.

# %%
def plot_z(z_gt, z_pred):
    plt.figure(figsize=(12, 4))
    
    plt.subplot(121)
    for i in range(0, 16):
        plt.plot(range(0, 1024), z_gt[:, i])
    
    plt.subplot(122)
    for i in range(0, 16):
        plt.plot(range(0, 1024), z_pred[:, i])
    
    plt.show()

# %%
generator = data.data_generator('d:/soundofai/complete_data', 'test', 1)

encoder = models.create_encoder(16, 16)
decoder = models.create_decoder(16, 16)
z_vae = models.VAE(encoder, decoder)

_ = z_vae(next(generator))

z_vae.load_weights('best.h5')
# Out:
# WARNING:tensorflow:Layer vae is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# WARNING:tensorflow:Layer vae is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.

# %%
z_gt, _ = next(generator)

z_pred = z_vae(z_gt)

plot_z(z_gt[0], z_pred[0])
