# %%
from IPython.display import Audio
import numpy as np
import os
from fb_qualities import FBQuality, get_audio, FBQualities

qs = FBQualities()
qs.build()

base_dir = "d:\soundofai\\all_nsynth_audio"
files = [x for x in os.listdir(base_dir) if x.lower().endswith(".wav")]

# %%
q = FBQuality("thin", [20, 400], [0, 0.08])

file = np.random.choice(files)
file_path = os.path.join(base_dir, file)

audio = get_audio(file_path)

r, fr = q.get_ratio_and_sliced_fr(audio)

print(r)
# Out:
# 0.503758

# %%
Audio(file_path, rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
qs.get_qualities_for(audio)
# Out:
# ['warm', 'muddy']

# %%
qs.rebuild()

# %%
qs.muddy.get_ratio(audio)
# Out:
# 0.503758
